# %% [markdown]
# # Matplotlib

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
plt.style.use('seaborn-v0_8-whitegrid')

# %%
plt.plot()
# Out:
# []

# %%
x = [1, 2, 3, 4]
y = [10,  8, 9 , 20]
plt.plot(x, y, color = "yellow")

# %% [markdown]
# ## Pyplot APiI vs Object-Oriented(OO) API
# + Pyplot API --> Quickly
# + OO APU --> Advanced

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), color = "Green", linestyle = "dashed", label = "sin(x)")
plt.plot(x, np.cos(x), color = "red", label = "cos(x)")
plt.xlabel("X")
plt.ylabel("F(x)")
plt.legend()
plt.title("Sin(x) and Cos(x)")
# plt.axis([0, 4, -0.7, 0.6])
plt.axis("equal")
# Out:
# (np.float64(-0.5),
#  np.float64(10.5),
#  np.float64(-1.0999987378908789),
#  np.float64(1.0999999398995657))

# %%
#1. Prepare data 
x = [1, 2,3, 5]
y = [11, 22, 33, 55]

#2. Setup plot 
fig, ax = plt.subplots(figsize = (5, 5))

#3. Plot the data
ax.plot(x, y)

ax.set(title = "A simple plot", xlabel = "x- axis", ylabel = "y -axis")
# Out:
# [Text(0.5, 1.0, 'A simple plot'),
#  Text(0.5, 0, 'x- axis'),
#  Text(0, 0.5, 'y -axis')]

# %% [markdown]
# ## 2. Most common types of Matplotlib plots
# * line
# * scatter
# * bar
# * hist
# * subplots()

# %% [markdown]
# ### Line

# %%
x = np.linspace(0, 10 , 100)
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
fig, ax = plt.subplots()
ax.plot(x, x**3)

# %% [markdown]
# ### Scatter

# %%
#pyplot API
plt.scatter(x, np.exp(x))

# %%
## 00 API
rng = np.random.RandomState(0)
x = rng.rand(100)
y = rng.rand(100)
color = rng.rand(100)
fig, ax = plt.subplots()
img1 = ax.scatter(x, y, c = color, cmap = 'viridis')
fig.colorbar(img1)

# %% [markdown]
# ## 3. Bar
# * Horinzontal
# * Vertical

# %%
soft_dirnk_prices = {"Coke" : 10, 
                     "Pepsi": 12, 
                     "Sprite": 11}
fig, ax = plt.subplots()
ax.set(title="Go Mart", ylabel="Price($)")
ax.bar(soft_dirnk_prices.keys(), soft_dirnk_prices.values())
# Out:
# <BarContainer object of 3 artists>

# %%
fig, ax = plt.subplots()
ax.barh(list(soft_dirnk_prices.keys()), list(soft_dirnk_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### Histogram

# %%
np.random.seed(42)
student_height = np.random.normal(170, 10, 250)
student_height [:10], len(student_height)
# Out:
# (array([174.96714153, 168.61735699, 176.47688538, 185.23029856,
#         167.65846625, 167.65863043, 185.79212816, 177.67434729,
#         165.30525614, 175.42560044]),
#  250)

# %%
plt.hist(student_height, bins = 40)
# Out:
# (array([ 1.,  0.,  0.,  2.,  4.,  2.,  4.,  8.,  9.,  8., 10., 15., 12.,
#         14., 18., 12., 16., 18., 20., 16., 12., 14., 10.,  3.,  3.,  8.,
#          0.,  5.,  0.,  2.,  1.,  1.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,
#          1.]),
#  array([143.80254896, 145.42066811, 147.03878726, 148.65690641,
#         150.27502555, 151.8931447 , 153.51126385, 155.129383  ,
#         156.74750215, 158.3656213 , 159.98374045, 161.60185959,
#         163.21997874, 164.83809789, 166.45621704, 168.07433619,
#         169.69245534, 171.31057449, 172.92869364, 174.54681278,
#         176.16493193, 177.78305108, 179.40117023, 181.01928938,
#         182.63740853, 184.25552768, 185.87364682, 187.49176597,
#         189.10988512, 190.72800427, 192.34612342, 193.96424257,
#         195.58236172, 197.20048087, 198.81860001, 200.43671916,
#         202.05483831, 203.67295746, 205.29107661, 206.90919576,
#         208.52731491]),
#  <BarContainer object of 40 artists>)

# %% [markdown]
# ## Subplots
# * Multiple plots on one figures: https://matplotlib.org/3.1.1/gallery/recipes/create_subplots.html

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10, 5))
ax1.plot(x, x/2)
ax1.plot(x, x*2)

ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(soft_dirnk_prices.keys(), soft_dirnk_prices.values())
ax4.hist(student_height, bins=30)
# Out:
# (array([ 1.,  0.,  2.,  5.,  4.,  9., 11., 12., 19., 21., 15., 20., 21.,
#         30., 19., 21., 11.,  7.,  6.,  5.,  5.,  0.,  3.,  1.,  1.,  0.,
#          0.,  0.,  0.,  1.]),
#  array([143.80254896, 145.96004116, 148.11753336, 150.27502555,
#         152.43251775, 154.59000995, 156.74750215, 158.90499435,
#         161.06248655, 163.21997874, 165.37747094, 167.53496314,
#         169.69245534, 171.84994754, 174.00743973, 176.16493193,
#         178.32242413, 180.47991633, 182.63740853, 184.79490073,
#         186.95239292, 189.10988512, 191.26737732, 193.42486952,
#         195.58236172, 197.73985392, 199.89734611, 202.05483831,
#         204.21233051, 206.36982271, 208.52731491]),
#  <BarContainer object of 30 artists>)

# %%
# Option 2:
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10,5))
#Plot data to each axis
ax[0,0].plot(x, x/2)
ax[0,0].plot(x, x*2)

ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(soft_dirnk_prices.keys(), soft_dirnk_prices.values())
ax[1,1].hist(student_height, bins=30)
# Out:
# (array([ 1.,  0.,  2.,  5.,  4.,  9., 11., 12., 19., 21., 15., 20., 21.,
#         30., 19., 21., 11.,  7.,  6.,  5.,  5.,  0.,  3.,  1.,  1.,  0.,
#          0.,  0.,  0.,  1.]),
#  array([143.80254896, 145.96004116, 148.11753336, 150.27502555,
#         152.43251775, 154.59000995, 156.74750215, 158.90499435,
#         161.06248655, 163.21997874, 165.37747094, 167.53496314,
#         169.69245534, 171.84994754, 174.00743973, 176.16493193,
#         178.32242413, 180.47991633, 182.63740853, 184.79490073,
#         186.95239292, 189.10988512, 191.26737732, 193.42486952,
#         195.58236172, 197.73985392, 199.89734611, 202.05483831,
#         204.21233051, 206.36982271, 208.52731491]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# # Project: Data Visualization - California Cities

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
cities = pd.read_csv("./california_cities.csv")
cities.head()
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
#    area_total_km2  area_land_km2  area_water_km2  area_water_percent
# 0         145.107        145.062           0.046                0.03
# 1          20.260         20.184           0.076                0.37
# 2          59.465         27.482          31.983               53.79
# 3          14.155          4.632           9.524               67.28
# 4          19.766         19.763           0.003                0.01

# %%
lat, lon = cities['latd'], cities['longd']
population, area = cities['population_total'], cities['area_total_km2']

plt.figure(figsize=(8,6))
# Plot using Pyplot API
plt.scatter(lon, lat, 
            c=np.log10(population), cmap='viridis',
            s=area, linewidths=0, alpha=0.5)

plt.axis('equal')
plt.xlabel('longlatitude')
plt.ylabel('latitude')
plt.colorbar(label='log$_{10}$(population)')
plt.clim(3,7)


#Create a legend for cities'sizes
area_range = [50, 100, 300, 500]

for area in area_range:
    plt.scatter([], [],  s=area, c='k', alpha=0.4,
                label=str(area) + ' km$^2$')

plt.legend(labelspacing=1, title='City Area')


plt.title('California Cities: Population and Area Distribution')
# Out:
# Text(0.5, 1.0, 'California Cities: Population and Area Distribution')
